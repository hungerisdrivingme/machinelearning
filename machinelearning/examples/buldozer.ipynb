# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from IPython.display import display
from sklearn import metrics

# %%
import pandas as pd
import numpy as np
import math

# %%
df=pd.read_csv("train.csv")
df.head(5)
# Out:
# C:\Users\hsyn_\AppData\Local\Temp\ipykernel_10332\1355906686.py:1: DtypeWarning: Columns (13,39,40,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("train.csv")
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246      66000     999089     3157         121           3.0      2004
# 1  1139248      57000     117657       77         121           3.0      1996
# 2  1139249      10000     434808     7009         121           3.0      2001
# 3  1139251      38500    1026470      332         121           3.0      2001
# 4  1139253      11000    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand         saledate  ...  \
# 0                      68.0       Low  11/16/2006 0:00  ...
# 1                    4640.0       Low   3/26/2004 0:00  ...
# 2                    2838.0      High   2/26/2004 0:00  ...
# ...

# %%
def display_all(df1):
    with pd.option_context("display.max_rows",100,"display.max_columns",100):
        display(df1)

# %%
display_all(df.tail())
# Out:
#         SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  \
# 401120  6333336      10500    1840702    21439         149           1.0
# 401121  6333337      11000    1830472    21439         149           1.0
# 401122  6333338      11500    1887659    21439         149           1.0
# 401123  6333341       9000    1903570    21435         149           2.0
# 401124  6333342       7750    1926965    21435         149           2.0
#
#         YearMade  MachineHoursCurrentMeter UsageBand         saledate  \
# 401120      2005                       NaN       NaN   11/2/2011 0:00
# 401121      2005                       NaN       NaN   11/2/2011 0:00
# 401122      2005                       NaN       NaN   11/2/2011 0:00
# 401123      2005                       NaN       NaN  10/25/2011 0:00
# 401124      2005                       NaN       NaN  10/25/2011 0:00
#
#        fiModelDesc fiBaseModel fiSecondaryDesc fiModelSeries  \
# ...

# %%
df.isnull().sum()
# Out:
# SalesID                          0
# SalePrice                        0
# MachineID                        0
# ModelID                          0
# datasource                       0
# auctioneerID                 20136
# YearMade                         0
# MachineHoursCurrentMeter    258360
# UsageBand                   331486
# saledate                         0
# fiModelDesc                      0
# fiBaseModel                      0
# fiSecondaryDesc             137191
# fiModelSeries               344217
# fiModelDescriptor           329206
# ProductSize                 210775
# fiProductClassDesc               0
# state                            0
# ProductGroup                     0
# ProductGroupDesc                 0
# Drive_System                296764
# Enclosure                      325
# Forks                       209048
# Pad_Type                    321991
# Ride_Control                252519
# Stick                       321991
# Transmission                217895
# ...

# %%
display_all(df.tail().T)
# Out:
#                                                                      401120  \
# SalesID                                                             6333336
# SalePrice                                                             10500
# MachineID                                                           1840702
# ModelID                                                               21439
# datasource                                                              149
# auctioneerID                                                            1.0
# YearMade                                                               2005
# MachineHoursCurrentMeter                                                NaN
# UsageBand                                                               NaN
# saledate                                                     11/2/2011 0:00
# fiModelDesc                                                           35NX2
# ...

# %%
df["SalePrice"]=np.log(df.SalePrice) #RMSLE kullanacagız. Bu sebeple sonucun logaritmasını aldık

# %%
df["SalePrice"]
# Out:
# 0         11.097410
# 1         10.950807
# 2          9.210340
# 3         10.558414
# 4          9.305651
#             ...
# 401120     9.259131
# 401121     9.305651
# 401122     9.350102
# 401123     9.104980
# 401124     8.955448
# Name: SalePrice, Length: 401125, dtype: float64

# %%
import re
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype

# %%
df_compare=df.copy()

# %%
df_compare.drop("saledate",axis=1, inplace=True)

# %%
re.sub('[Dd]ate$',"","saledate") # delete "date" or "Date" from name
# Out:
# 'sale'

# %%
df['saledate'] = pd.to_datetime(df['saledate'], errors='coerce')
df["saledate"]
# Out:
# 0        2006-11-16
# 1        2004-03-26
# 2        2004-02-26
# 3        2011-05-19
# 4        2009-07-23
#             ...
# 401120   2011-11-02
# 401121   2011-11-02
# 401122   2011-11-02
# 401123   2011-10-25
# 401124   2011-10-25
# Name: saledate, Length: 401125, dtype: datetime64[ns]

# %%
df['saledate'].dt.year
# Out:
# 0         2006
# 1         2004
# 2         2004
# 3         2011
# 4         2009
#           ...
# 401120    2011
# 401121    2011
# 401122    2011
# 401123    2011
# 401124    2011
# Name: saledate, Length: 401125, dtype: int64

# %%
def add_datepart(df2,dt_name,drop=True,time=False): #creates new columns from our dt column
                                                    #optimal spliti yapabilmesi icin hangi günlerin haftasonu
                                                    #oldugunu sisteme ögretmek icin ayırıyoruz.
    dt_column=df2[dt_name]
    column_dtype=dt_column.dtype
    targ_name=re.sub('[Dd]ate$','',dt_name)
    
    attr=['Year','Month','Week','Day','Dayofweek','Dayofyear','Is_month_end',
         'Is_month_start','Is_quarter_end','Is_quarter_start','Is_year_end','Is_year_start']
    
    if time:
        attr=attr+['Hour','Minute','Second']
        
    for a in attr:
        df2[targ_name+a]=getattr(dt_column.dt,a.lower())
    #howmuch time passed,we will divide by 10^9 because it is in the nanosec format   
    df2[targ_name+'Elapsed']=dt_column.astype(np.int64)//10**9
    
    if drop:
        df2.drop(dt_name,axis=1,inplace=True)

# %%
add_datepart(df,"saledate")
# Out:
# C:\Users\hsyn_\AppData\Local\Temp\ipykernel_10332\3814271645.py:15: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df2[targ_name+a]=getattr(dt_column.dt,a.lower())

# %%
display_all(df.head().T)
# Out:
#                                                                  0  \
# SalesID                                                    1139246
# SalePrice                                                 11.09741
# MachineID                                                   999089
# ModelID                                                       3157
# datasource                                                     121
# auctioneerID                                                   3.0
# YearMade                                                      2004
# MachineHoursCurrentMeter                                      68.0
# UsageBand                                                      Low
# fiModelDesc                                                   521D
# fiBaseModel                                                    521
# fiSecondaryDesc                                                  D
# fiModelSeries                                                  NaN
# ...

# %%
df.items()
# Out:
# <generator object DataFrame.items at 0x000001CB292CB8B0>

# %%
a=df.items()

# %%
next(a)
# Out:
# ('SalesID',
#  0         1139246
#  1         1139248
#  2         1139249
#  3         1139251
#  4         1139253
#             ...
#  401120    6333336
#  401121    6333337
#  401122    6333338
#  401123    6333341
#  401124    6333342
#  Name: SalesID, Length: 401125, dtype: int64)

# %%
#train kısmı
def train_cats(df2):
    for n,c in df2.items():  #n column name,  c series,, Tuple donduruyor ilk elemanı n ikinci el c
        if is_string_dtype(c):  #string dtypeı pandas kategoriye cevirir
            df[n]=c.astype("category").cat.as_ordered()

# %%
#traine train_cats uyguladıktan sonra aynı degişimleri validation ve teste de uygulamalıyız
#validation kısmı    #amac traine yapılan kategorik islemin aynısının test ve valid'e de uygulanması
def apply_cats(df2,train):
    for n,c in df2.items():
        if train[n].dtype=="category":
            df2[n]=pd.Categorical(c,categories=train[n].cat.categories,ordered= True)

# %%
df2=df.copy()

# %%
df2.head()
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246  11.097410     999089     3157         121           3.0      2004
# 1  1139248  10.950807     117657       77         121           3.0      1996
# 2  1139249   9.210340     434808     7009         121           3.0      2001
# 3  1139251  10.558414    1026470      332         121           3.0      2001
# 4  1139253   9.305651    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand fiModelDesc  ... saleDay saleDayofweek  \
# 0                      68.0       Low        521D  ...      16             3
# 1                    4640.0       Low      950FII  ...      26             4
# 2                    2838.0      High         226  ...      26             3
# 3                    3486.0      High    PC120-6E  ...      19             3
# 4                     722.0    Medium        S175  ...      23             3
#
# ...

# %%
train_cats(df2)

# %%
train_cats(df_compare)

# %%
df2.head()
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246  11.097410     999089     3157         121           3.0      2004
# 1  1139248  10.950807     117657       77         121           3.0      1996
# 2  1139249   9.210340     434808     7009         121           3.0      2001
# 3  1139251  10.558414    1026470      332         121           3.0      2001
# 4  1139253   9.305651    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand fiModelDesc  ... saleDay saleDayofweek  \
# 0                      68.0       Low        521D  ...      16             3
# 1                    4640.0       Low      950FII  ...      26             4
# 2                    2838.0      High         226  ...      26             3
# 3                    3486.0      High    PC120-6E  ...      19             3
# 4                     722.0    Medium        S175  ...      23             3
#
# ...

# %%
df2["UsageBand"]
# Out:
# 0            Low
# 1            Low
# 2           High
# 3           High
# 4         Medium
#            ...
# 401120       NaN
# 401121       NaN
# 401122       NaN
# 401123       NaN
# 401124       NaN
# Name: UsageBand, Length: 401125, dtype: object

# %%
df2["UsageBand"].astype('category').values
#df2["UsageBand"].cat.categories
# Out:
# ['Low', 'Low', 'High', 'High', 'Medium', ..., NaN, NaN, NaN, NaN, NaN]
# Length: 401125
# Categories (3, object): ['High', 'Low', 'Medium']

# %%
df2["UsageBand"].astype('category').values.set_categories(["High","Medium","Low"],ordered=True,inplace=True)
#df2["UsageBand"].cat.set_categories(["High","Medium","Low"],ordered=True,inplace=True)
# kategori sıralamasını high med low olarak degistirdik
# Out:
# C:\Users\hsyn_\AppData\Local\Temp\ipykernel_10332\2656900305.py:1: FutureWarning: The `inplace` parameter in pandas.Categorical.set_categories is deprecated and will be removed in a future version. Removing unused categories will always return a new Categorical object.
#   df2["UsageBand"].astype('category').values.set_categories(["High","Medium","Low"],ordered=True,inplace=True)

# %%
df2["UsageBand"].astype('category').values
#df2["UsageBand"].cat.categories
# Out:
# ['Low', 'Low', 'High', 'High', 'Medium', ..., NaN, NaN, NaN, NaN, NaN]
# Length: 401125
# Categories (3, object): ['High', 'Low', 'Medium']

# %%
df2["UsageBand"].astype('category').values.codes
# Out:
# array([ 1,  1,  0, ..., -1, -1, -1], dtype=int8)

# %%
#Missing of the entry can also be a valuable information
#So we will create a column that is False when value is missing
#We encoded missingness in categorical columns so we will just create _na columns for numerical types
def fix_missing(df2,col,name):
    if is_numeric_dtype(col): #numerik mi?
        if pd.isnull(col).sum: #null var mı? 0 false 1 true
            df2[name+"_na"]=pd.isnull(col)  #column yarattık
        df2[name]=col.fillna(col.median())   #missing valueları medyan ile degistirdi

# %%
def numericalize(df2,col,name):
    if not is_numeric_dtype(col):
        df2[name]=col.astype('category').values.codes+1      # missing valuelar -1 degil 0 olsun diye

# %%
def proc_df(df2,y_fld):
    y=df2[y_fld].values
    df2.drop([y_fld],axis=1,inplace=True)
    for n,c in df2.items():
        fix_missing(df2,c,n)
    for n,c in df2.items():
        numericalize(df2,c,n)
    res=[df2,y]
    
    return res

# %%
df2,y=proc_df(df2,"SalePrice")

# %%
df_compare,y_compare=proc_df(df_compare,"SalePrice")

# %%
df2.columns
# Out:
# Index(['SalesID', 'MachineID', 'ModelID', 'datasource', 'auctioneerID',
#        'YearMade', 'MachineHoursCurrentMeter', 'UsageBand', 'fiModelDesc',
#        'fiBaseModel', 'fiSecondaryDesc', 'fiModelSeries', 'fiModelDescriptor',
#        'ProductSize', 'fiProductClassDesc', 'state', 'ProductGroup',
#        'ProductGroupDesc', 'Drive_System', 'Enclosure', 'Forks', 'Pad_Type',
#        'Ride_Control', 'Stick', 'Transmission', 'Turbocharged',
#        'Blade_Extension', 'Blade_Width', 'Enclosure_Type', 'Engine_Horsepower',
#        'Hydraulics', 'Pushblock', 'Ripper', 'Scarifier', 'Tip_Control',
#        'Tire_Size', 'Coupler', 'Coupler_System', 'Grouser_Tracks',
#        'Hydraulics_Flow', 'Track_Type', 'Undercarriage_Pad_Width',
#        'Stick_Length', 'Thumb', 'Pattern_Changer', 'Grouser_Type',
#        'Backhoe_Mounting', 'Blade_Type', 'Travel_Controls',
#        'Differential_Type', 'Steering_Controls', 'saleYear', 'saleMonth',
# ...

# %%
y
# Out:
# array([11.09741002, 10.95080655,  9.21034037, ...,  9.35010231,
#         9.10497986,  8.95544812])

# %%
display_all(df.tail().T)
# Out:
#                                                                      401120  \
# SalesID                                                             6333336
# SalePrice                                                          9.259131
# MachineID                                                           1840702
# ModelID                                                               21439
# datasource                                                              149
# auctioneerID                                                            1.0
# YearMade                                                               2005
# MachineHoursCurrentMeter                                                NaN
# UsageBand                                                               NaN
# fiModelDesc                                                           35NX2
# fiBaseModel                                                              35
# ...

# %%
m=RandomForestRegressor(n_jobs=-1)
m.fit(df2,y)
m.score(df2,y)
# Out:
# 0.988175311633499
